# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Data Structures > 02. Introduction to data structures
#
#
# **[<< Previous lesson](./01_Computational-complexity.ipynb)   |   [Next lesson >>](./03_Arrays.ipynb)**
#
# <hr>
# &nbsp;

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Overview" data-toc-modified-id="Overview-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Overview</a></span></li></ul></div>

# %% [markdown]
# <hr>
# &nbsp;
#
# ## Introduction

# %%
YouTubeVideo('bum_19loj9A',width=560,height=315)

# %% [markdown]
# <hr>
# &nbsp;
#
#
# ## Overview
#
# &nbsp;
#
# <img src="./attachments/Data_Structure_Operations.png" alt="Data structure operations">
