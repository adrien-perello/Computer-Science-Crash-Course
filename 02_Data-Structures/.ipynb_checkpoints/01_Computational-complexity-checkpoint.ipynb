# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Data Structures > 01. Computational complexity
#
#
# **[<< Previous lesson](../01_Introduction-to-Python/23_Clean-code.ipynb)   |   [Next lesson >>](./02_Introduction-to-data-structures.ipynb)**
#
# <hr>
# &nbsp;

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Going-further" data-toc-modified-id="Going-further-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Going further</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Summary</a></span></li></ul></div>

# %% [markdown]
# <hr>
# &nbsp;
#
# ## Introduction

# %%
YouTubeVideo('v4cd1O4zkGw',width=560,height=315)

# %% [markdown]
# <hr>
# &nbsp;
#
# ## Going further

# %%
YouTubeVideo('l-cNaKGc-yY',width=560,height=315)

# %%
YouTubeVideo('QfRSeibcugw',width=560,height=315)

# %%
YouTubeVideo('5rZCkblZFZM',width=560,height=315)

# %% [markdown]
# <hr>
# &nbsp;
#
#
# ## Summary
#
# &nbsp;
#
# <img src="./attachments/Big-O_Complexity_Chart.png" alt="Big O complexity chart">
